# %%
import duckdb
import pandas as pd
import polars as pl

# %% [markdown]
# ## Read using duckdb method

# %% [markdown]
# ### Reading from a file directly
#
# This is if the notebook is in the same folder as the file itself

# %%
duckdb.sql("SELECT *FROM PM_AutoGDPItem_SDPB.parquet LIMIT 100").pl().limit(10)
# Out:
# shape: (10, 44)
# ┌────────────┬────────────┬────────┬────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ ProfitReco ┆ ProfitReco ┆ UnitID ┆ SaleID ┆ … ┆ SalesRecog ┆ SalesRecog ┆ AmtMoreTha ┆ AmtMoreTha │
# │ gnizeItemI ┆ gnizeID    ┆ ---    ┆ ---    ┆   ┆ nition     ┆ nitionMetD ┆ nSPA       ┆ nSPAMetDat │
# │ D          ┆ ---        ┆ i32    ┆ i32    ┆   ┆ ---        ┆ ate        ┆ ---        ┆ e          │
# │ ---        ┆ i32        ┆        ┆        ┆   ┆ str        ┆ ---        ┆ str        ┆ ---        │
# │ i32        ┆            ┆        ┆        ┆   ┆            ┆ datetime[μ ┆            ┆ datetime[μ │
# │            ┆            ┆        ┆        ┆   ┆            ┆ s]         ┆            ┆ s]         │
# ╞════════════╪════════════╪════════╪════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 17419480   ┆ 126561     ┆ 54543  ┆ 40750  ┆ … ┆ Y          ┆ null       ┆ null       ┆ 1900-01-01 │
# ...

# %% [markdown]
# ### Reading from a folder

# %%
duckdb.read_parquet(r'C:\Users\ahmad.azwan\Downloads\userdata1.parquet').pl().limit(5)
# Out:
# shape: (5, 13)
# ┌────────────┬─────┬────────────┬───────────┬───┬───────────┬───────────┬───────────────┬──────────┐
# │ registrati ┆ id  ┆ first_name ┆ last_name ┆ … ┆ birthdate ┆ salary    ┆ title         ┆ comments │
# │ on_dttm    ┆ --- ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---           ┆ ---      │
# │ ---        ┆ i32 ┆ str        ┆ str       ┆   ┆ str       ┆ f64       ┆ str           ┆ str      │
# │ datetime[μ ┆     ┆            ┆           ┆   ┆           ┆           ┆               ┆          │
# │ s]         ┆     ┆            ┆           ┆   ┆           ┆           ┆               ┆          │
# ╞════════════╪═════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════════╪══════════╡
# │ 2016-02-03 ┆ 1   ┆ Amanda     ┆ Jordan    ┆ … ┆ 3/8/1971  ┆ 49756.53  ┆ Internal      ┆ 1E+02    │
# │ 07:55:29   ┆     ┆            ┆           ┆   ┆           ┆           ┆ Auditor       ┆          │
# ...

# %% [markdown]
# ## Read using connection method

# %%
con = duckdb.connect()

# %%
con.execute("""SELECT *FROM PM_AutoGDPItem_SDPB.parquet""").df()
# Out:
#        ProfitRecognizeItemID  ProfitRecognizeID  UnitID    SaleID IsUnitSold  \
# 0                   17419480             126561   54543   40750.0          Y
# 1                   17419481             126561   54471   39261.0          Y
# 2                   17419482             126561   54472   39255.0          Y
# 3                   17419483             126561   54489   45108.0          Y
# 4                   17419484             126561   54522   39345.0          Y
# ...                      ...                ...     ...       ...        ...
# 44341               17458921             126875   72128   72143.0          Y
# 44342               17458922             126876   77063   99431.0          Y
# 44343               17458923             126877   80738  110624.0          Y
# 44344               17458924             126877   80737  110623.0          Y
# 44345               17458925             126877   80739  109534.0          Y
#
# ...

# %%
# con.close()

# %% [markdown]
# ## Read using JupySQL extension

# %%
# %load_ext sql

# %%
# %sql duckdb:///:memory:

# %%
# %%sql
# -- INSTALL httpfs;
# LOAD httpfs;
# Out:
# *  duckdb:///:memory:
# Done.
# []

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %%sql
#
# SELECT * FROM 'PM_AutoGDPItem_SDPB.parquet'
# Out:
#        ProfitRecognizeItemID  ProfitRecognizeID  UnitID    SaleID IsUnitSold  \
# 0                   17419480             126561   54543   40750.0          Y
# 1                   17419481             126561   54471   39261.0          Y
# 2                   17419482             126561   54472   39255.0          Y
# 3                   17419483             126561   54489   45108.0          Y
# 4                   17419484             126561   54522   39345.0          Y
# ...                      ...                ...     ...       ...        ...
# 44341               17458921             126875   72128   72143.0          Y
# 44342               17458922             126876   77063   99431.0          Y
# 44343               17458923             126877   80738  110624.0          Y
# 44344               17458924             126877   80737  110623.0          Y
# 44345               17458925             126877   80739  109534.0          Y
#
# ...

# %% [markdown]
# ### Reading from HTTP

# %%
# %%sql
# SELECT *
# FROM "https://github.com/Teradata/kylo/blob/master/samples/sample-data/parquet/userdata1.parquet?raw=true"
# LIMIT 1000
# Out:
#       registration_dttm    id first_name last_name                     email  \
# 0   2016-02-03 07:55:29     1     Amanda    Jordan          ajordan0@com.com
# 1   2016-02-03 17:04:03     2     Albert   Freeman           afreeman1@is.gd
# 2   2016-02-03 01:09:31     3     Evelyn    Morgan   emorgan2@altervista.org
# 3   2016-02-03 00:36:21     4     Denise     Riley          driley3@gmpg.org
# 4   2016-02-03 05:05:31     5     Carlos     Burns  cburns4@miitbeian.gov.cn
# ..                  ...   ...        ...       ...                       ...
# 995 2016-02-03 10:30:59   996     Dennis    Harris      dharrisrn@eepurl.com
# 996 2016-02-03 17:16:53   997     Gloria  Hamilton    ghamiltonro@rambler.ru
# 997 2016-02-03 05:02:20   998      Nancy    Morris         nmorrisrp@ask.com
# 998 2016-02-03 02:41:32   999      Annie   Daniels    adanielsrq@squidoo.com
# 999 2016-02-03 09:52:18  1000      Julie     Meyer       jmeyerrr@flavors.me
#
# ...
